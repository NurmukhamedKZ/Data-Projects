# %%
import camelot
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
grant_B057 = camelot.read_pdf("data/B057_all.pdf", pages="all", flavor="lattice", suppress_stdout=False)

# %%
# for rollback the table
collect_grant_B057 = pd.DataFrame({0: [],
                              1: [],
                              2: [],
                              3: [],
                              4: []})

for page in grant_B057:
    collect_grant_B057 = pd.concat([collect_grant_B057, page.df], ignore_index=True)

# %%
collect_grant_B057.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4959 entries, 0 to 4958
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       4959 non-null   object
#  1   1       4959 non-null   object
#  2   2       4959 non-null   object
#  3   3       4959 non-null   object
#  4   4       4959 non-null   object
# dtypes: object(5)
# memory usage: 193.8+ KB

# %%
# Parsing
collect_grant_B057.rename(columns={0:"#",1:"id",2:"name",3:"score",4:"university"}, inplace=True) 

collect_grant_B057["name"] = collect_grant_B057["name"].str.replace("\n","")
collect_grant_B057["#"] = collect_grant_B057["#"].str.replace("\n","")

cnt_of_starts = 0
for i, row in collect_grant_B057.iterrows():
    if row["#"] == "":
        collect_grant_B057.loc[i-1, "name"] += " " + collect_grant_B057.loc[i,"name"]
        collect_grant_B057.drop(i, inplace=True)
    elif len(row["#"]) >=7:
        collect_grant_B057.drop(i, inplace=True) 
    elif row["#"] == "1":
        cnt_of_starts += 1
        if cnt_of_starts == 2:
            collect_grant_B057.drop(i, inplace=True)
    elif cnt_of_starts == 2:
        collect_grant_B057.drop(i, inplace=True)

if collect_grant_B057.iloc[0,0] != 1:
    for i, row in collect_grant_B057.iterrows():
        if row["#"] == "1":
            break
        else:
            collect_grant_B057.drop(i, inplace=True)
        
# Sharing
collect_grant_B057.to_csv("data/grants_B057.csv", index=False)

# %% [markdown]
# # B058

# %%
grant_B058 = camelot.read_pdf("data/B058_all.pdf", pages="all", flavor="lattice", suppress_stdout=False)

# %%
# for rollback the table
collect_grant_B058 = pd.DataFrame({0: [],
                              1: [],
                              2: [],
                              3: [],
                              4: []})

for page in grant_B058:
    collect_grant_B058 = pd.concat([collect_grant_B058, page.df], ignore_index=True)

# %%
# Parsing
collect_grant_B058.rename(columns={0:"#",1:"id",2:"name",3:"score",4:"university"}, inplace=True) 

collect_grant_B058["name"] = collect_grant_B058["name"].str.replace("\n","")
collect_grant_B058["#"] = collect_grant_B058["#"].str.replace("\n","")

cnt_of_starts = 0
for i, row in collect_grant_B058.iterrows():
    if row["#"] == "":
        collect_grant_B058.loc[i-1, "name"] += " " + collect_grant_B058.loc[i,"name"]
        collect_grant_B058.drop(i, inplace=True)
    elif len(row["#"]) >=7:
        collect_grant_B058.drop(i, inplace=True) 
    elif row["#"] == "1":
        cnt_of_starts += 1
        if cnt_of_starts == 2:
            collect_grant_B058.drop(i, inplace=True)
    elif cnt_of_starts == 2:
        collect_grant_B058.drop(i, inplace=True)

if collect_grant_B058.iloc[0,0] != 1:
    for i, row in collect_grant_B058.iterrows():
        if row["#"] == "1":
            break
        else:
            collect_grant_B058.drop(i, inplace=True)

        
# Sharing
collect_grant_B058.to_csv("data/grants_B058.csv", index=False)

# %% [markdown]
# # B011

# %%
grant_B011 = camelot.read_pdf("data/B011_all.pdf", pages="all", flavor="lattice", suppress_stdout=False)

# %%
# for rollback the table
collect_grant_B011 = pd.DataFrame({0: [],
                              1: [],
                              2: [],
                              3: [],
                              4: []})

for page in grant_B011:
    collect_grant_B011 = pd.concat([collect_grant_B011, page.df], ignore_index=True)

# %%
# Parsing
collect_grant_B011.rename(columns={0:"#",1:"id",2:"name",3:"score",4:"university"}, inplace=True) 

collect_grant_B011["name"] = collect_grant_B011["name"].str.replace("\n","")
collect_grant_B011["#"] = collect_grant_B011["#"].str.replace("\n","")

cnt_of_starts = 0
for i, row in collect_grant_B011.iterrows():
    if row["#"] == "":
        collect_grant_B011.loc[i-1, "name"] += " " + collect_grant_B011.loc[i,"name"]
        collect_grant_B011.drop(i, inplace=True)
    elif len(row["#"]) >=7:
        collect_grant_B011.drop(i, inplace=True) 
    elif row["#"] == "1":
        cnt_of_starts += 1
        if cnt_of_starts == 2:
            collect_grant_B011.drop(i, inplace=True)
    elif cnt_of_starts == 2:
        collect_grant_B011.drop(i, inplace=True)

if collect_grant_B011.iloc[0,0] != 1:
    for i, row in collect_grant_B011.iterrows():
        if row["#"] == "1":
            break
        else:
            collect_grant_B011.drop(i, inplace=True)

        
# Sharing
collect_grant_B011.to_csv("data/grants_B011.csv", index=False)

# %% [markdown]
# # B158

# %%
grant_B158 = camelot.read_pdf("data/B158_all.pdf", pages="all", flavor="lattice", suppress_stdout=False)

# %%
# for rollback the table
collect_grant_B158 = pd.DataFrame({0: [],
                              1: [],
                              2: [],
                              3: [],
                              4: []})

for page in grant_B158:
    collect_grant_B158 = pd.concat([collect_grant_B158, page.df], ignore_index=True)

# %%
# Parsing
collect_grant_B158.rename(columns={0:"#",1:"id",2:"name",3:"score",4:"university"}, inplace=True) 

collect_grant_B158["name"] = collect_grant_B158["name"].str.replace("\n","")
collect_grant_B158["#"] = collect_grant_B158["#"].str.replace("\n","")

cnt_of_starts = 0
for i, row in collect_grant_B158.iterrows():
    if row["#"] == "":
        collect_grant_B158.loc[i-1, "name"] += " " + collect_grant_B158.loc[i,"name"]
        collect_grant_B158.drop(i, inplace=True)
    elif len(row["#"]) >=7:
        collect_grant_B158.drop(i, inplace=True) 
    elif row["#"] == "1":
        cnt_of_starts += 1
        if cnt_of_starts == 2:
            collect_grant_B158.drop(i, inplace=True)
    elif cnt_of_starts == 2:
        collect_grant_B158.drop(i, inplace=True)

if collect_grant_B158.iloc[0,0] != 1:
    for i, row in collect_grant_B158.iterrows():
        if row["#"] == "1":
            break
        else:
            collect_grant_B158.drop(i, inplace=True)
        
# Sharing
collect_grant_B158.to_csv("data/grants_B158.csv", index=False)

# %%
# Collecting together

collect_grant_B057["grant_code"] = "B057"
collect_grant_B058["grant_code"] = "B058"
collect_grant_B011["grant_code"] = "B011"
collect_grant_B158["grant_code"] = "B158"

general_IT_grants = pd.concat([collect_grant_B057, collect_grant_B058, collect_grant_B011, collect_grant_B158])


general_IT_grants
# Out:
#      #         id                              name score university  \
# 2    1  003747073          АБИЛХАН ЖӘНІБЕК АСҚАРҰЛЫ   140        522
# 3    2  003919867                    ЕРМЕКҚЫЗЫ ӘСЕЛ   139        522
# 4    3  003919902         БАИМБЕТОВ ТАИР АМАНТАЕВИЧ   139        421
# 5    4  003474792     САТЫБАЛДИЕВА АНЕЛЯ ДОСБОЛОВНА   138        302
# 6    5  003463254  СУЛТАНБЕКОВ БАҚДӘУЛЕТ АСЫЛБЕКҰЛЫ   138        302
# ..  ..        ...                               ...   ...        ...
# 29  28  003467893        ПАДИКУЛОВ ДАУЛЕТ МЕДЕТОВИЧ   104        013
# 30  29  003631496          КОЖАХМЕТ АДИЛЬ НУРЛАНУЛЫ   103        013
# 31  30  003809613              БУРКУТ ДИАС АСКАРУЛЫ   103        013
# 32  31  003783405          АРИНОВ НАРИМАН СЕРИКОВИЧ   103        013
# 33  32  003832267            МАРАТ ӘДІЛЕТ ШЫНҒЫСҰЛЫ   103        013
#
#    grant_code
# 2        B057
# 3        B057
# 4        B057
# 5        B057
# 6        B057
# ..        ...
# 29       B158
# ...

# %%
grant_counts = pd.DataFrame(general_IT_grants.loc[:, ["score","grant_code"]].value_counts(sort=False).reset_index())

for i, row in grant_counts.iterrows():
    grant_counts.loc[i,"score"] = int(row.score)
grant_counts.sort_values(by=["score"], inplace=True)
grant_counts.to_csv("data/counts_test.csv", index=False)

# %%
g = sns.FacetGrid(grant_counts, col="grant_code", col_wrap=2, height=4, aspect=2)
g.map_dataframe(sns.barplot, x="score", y="count")

plt.tight_layout()
plt.show()

# %%
g = sns.FacetGrid(grant_counts, col="grant_code", col_wrap=2, height=4, aspect=2)
g.map_dataframe(sns.barplot, x="score", y="count")

for ax in g.axes.flat:
    ax.set_xticks(range(60, 141, 10))
    ax.set_xticklabels(ax.get_xticks(), rotation=45)

plt.tight_layout()
plt.show()

# It's incorrect

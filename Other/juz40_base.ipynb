# %%
import camelot
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
base1 = camelot.read_pdf("География---2-ай-3-апта-genius.pdf", pages="all", flavor="lattice", suppress_stdout=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 base1 = camelot.read_pdf("География---2-ай-3-апта-genius.pdf", pages="all", flavor="lattice", suppress_stdout=False)
#
# File ~/vscode_projects/data_projects/.venv/lib/python3.13/site-packages/camelot/io.py:134, in read_pdf(filepath, pages, password, flavor, suppress_stdout, parallel, layout_kwargs, debug, **kwargs)
#     132 p = PDFHandler(filepath, pages=pages, password=password, debug=debug)
#     133 kwargs = remove_extra(kwargs, flavor=flavor)
# --> 134 tables = p.parse(
#     135     flavor=flavor,
#     136     suppress_stdout=suppress_stdout,
#     137     parallel=parallel,
#     138     layout_kwargs=layout_kwargs,
#     139     **kwargs,
#     140 )
#     141 return tables
#
# ...

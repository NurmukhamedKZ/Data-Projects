# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
data = pd.read_excel("Динамика СЭП РК 1991-2024 (англ).xls")
data.head(10)
# Out:
#   The main socio-economic indicators of the Republic of Kazakhstan Unnamed: 1  \
# 0                                                NaN                      NaN
# 1                             Update date 05.08.2025                      NaN
# 2                                                NaN                     1991
# 3                          Socio-economic indicators                      NaN
# 4         Population at the end of the period (year)                      NaN
# 5                                thousands of people                  16451.7
# 6               as a percentage of the previous year                    100.6
# 7  Life expectancy at birth of the population of ...                      NaN
# 8                                     all population                     67.6
# 9                                                men                     62.6
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# ...

# %%
data[4:]
# Out:
#     The main socio-economic indicators of the Republic of Kazakhstan  \
# 4           Population at the end of the period (year)
# 5                                  thousands of people
# 6                 as a percentage of the previous year
# 7    Life expectancy at birth of the population of ...
# 8                                       all population
# ..                                                 ...
# 284  17) The recalculation was carried out in accor...
# 285  18) In accordance with paragraph 2 of paragrap...
# 286  19) For 1990-2009, the data were compiled taki...
# 287                                                NaN
# 288                              20) Preliminary data.
#
#     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 4          NaN        NaN        NaN        NaN        NaN        NaN
# 5      16451.7    16426.5    16334.9    15956.7    15675.8    15480.6
# 6        100.6       99.8       99.4       97.7       98.2       98.8
# ...

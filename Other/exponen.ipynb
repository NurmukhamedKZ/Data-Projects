# %%
import pandas as pd
from scipy import stats

x = stats.expon.rvs(4, size=100)
pd.DataFrame(x).plot.hist(xlim=[0,10])
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Out:
# <Axes: ylabel='Frequency'>

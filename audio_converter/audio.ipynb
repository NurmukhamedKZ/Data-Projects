# %%
from openai import OpenAI

client = OpenAI(api_key="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")

with open("data/Дәулет Керей көшесі.m4a", "rb") as audio_file:
    transcript = client.audio.transcriptions.create(
        model="whisper-1",
        file=audio_file
    )

print("Transcription:", transcript.text)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[5], line 6
#       3 client = OpenAI(api_key="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")
#       5 with open("data/Дәулет Керей көшесі.m4a", "rb") as audio_file:
# ----> 6     transcript = client.audio.transcriptions.create(
#       7         model="whisper-1",
#       8         file=audio_file
#       9     )
#      11 print("Transcription:", transcript.text)
#
# File ~/vscode_projects/data_projects/.venv/lib/python3.13/site-packages/openai/_utils/_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# ...

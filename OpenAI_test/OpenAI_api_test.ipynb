# %%
from dotenv import load_dotenv
from openai import OpenAI
import os

load_dotenv()

OpenAI_API = os.getenv("OPENAI_API_KEY")

client = OpenAI(
    api_key=OpenAI_API
)

response = client.chat.completions.create(
    model="google/gemma-3-12b-it",
    messages=[{"role": "user",
               "content": "give me top 5 life lessons"}],
    temperature=0.7
)

message = response.choices[0].message.content
print(message)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[8], line 9
#       5 load_dotenv()
#       7 OpenAI_API = os.getenv("OPENAI_API_KEY")
# ----> 9 client = OpenAI(
#      10     api_key=OpenAI_API
#      11 )
#      13 response = client.chat.completions.create(
#      14     model="google/gemma-3-12b-it",
#      15     messages=[{"role": "user",
#      16                "content": "give me top 5 life lessons"}],
#      17     temperature=0.7
#      18 )
#      20 message = response.choices[0].message.content
#
# File ~/vscode_projects/data_projects/.venv/lib/python3.13/site-packages/openai/_client.py:130, in OpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     128     api_key = os.environ.get("OPENAI_API_KEY")
# ...

# %%
from openai import OpenAI


client = OpenAI(api_key="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")

response = client.chat.completions.create(
    model="gpt-4o-mini",  
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Explain quantum physics simply."}
    ]
)

print(response.choices[0].message.content)
# Out:
# Quantum physics is a branch of science that studies the very small particles that make up everything in the universe, like atoms and subatomic particles (which are even smaller than atoms). Here are some key ideas simplified:
#
# 1. **Particle-Wave Duality**: Particles like electrons can behave both like particles and like waves. This means they can sometimes act like little balls and at other times spread out like a wave.
#
# 2. **Quantization**: Energy, in the quantum world, comes in small, discrete packets called "quanta." For example, light behaves like a wave, but it is made up of tiny particles called photons, which exist in specific amounts of energy.
#
# 3. **Uncertainty Principle**: One of the most famous principles in quantum physics, formulated by Werner Heisenberg, states that there is a limit to how precisely we can know both the position and momentum of a particle at the same time. The more accurately we know one, the less accurately we can know the other.
#
# ...

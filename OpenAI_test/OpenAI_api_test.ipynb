# %%
from openai import OpenAI
from dotenv import load_dotenv, find_dotenv
import os

env_path = find_dotenv()
load_dotenv(env_path)

api_key1 = os.getenv("OPENAI_API_KEY")
print(api_key1)


real_api = "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"

print(api_key1 == real_api)
# client = OpenAI(api_key=api_key1)

# response = client.chat.completions.create(
#     model="gpt-4o-mini",  
#     messages=[
#         {"role": "system", "content": "You are a helpful assistant."},
#         {"role": "user", "content": "Explain quantum physics simply."}
#     ]
# )

# print(response.choices[0].message.content)
# Out:
# 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
# True

# %%
from openai import OpenAI


client = OpenAI(api_key="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")

response = client.chat.completions.create(
    model="gpt-4o-mini",  
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Explain quantum physics simply."}
    ]
)

print(response.choices[0].message.content)
# Out:
# Sure! Quantum physics, or quantum mechanics, is a branch of science that explores the behavior of very tiny particles, like atoms and subatomic particles (like electrons and photons). It describes the strange and counterintuitive ways these particles behave, which are very different from our everyday experiences. Here are some key concepts:
#
# 1. **Particles as Waves**: In quantum mechanics, particles can behave like waves. This means they can spread out and interfere with each other. For example, when electrons move, they can create patterns similar to waves in water.
#
# 2. **Uncertainty Principle**: One of the fundamental ideas in quantum physics is that you can't know everything about a particle at the same time. For example, if you know a particle's position very precisely, you can't know its momentum (speed and direction) accurately. This is known as the Heisenberg Uncertainty Principle.
#
# 3. **Superposition**: Particles can exist in multiple states at once until they are observed or measured. This is called superposition. A famous illustration of this is Schrödinger's cat, which is a thought experiment where a cat is both alive and dead until you check on it.
#
# 4. **Entanglement**: Particles can become entangled, meaning the state of one particle is connected to the state of another, no matter how far apart they are. This leads to the idea that measuring one particle can instantly affect the other.
#
# 5. **Quantization**: Many properties, like energy, are quantized, which means they come in discrete units (like steps on a ladder) rather than a continuous range.
#
# Quantum physics challenges our intuition and has profound implications for technology, leading to things like lasers, transistors, and even quantum computers. It shows that at the smallest scales, the universe operates in ways that are very different from our everyday experiences!
